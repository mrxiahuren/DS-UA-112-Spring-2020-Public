# %%
import pandas as pd

# %%
left = pd.DataFrame({'key': ['K0', 'K5','K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3','A4'],
                    'B': ['B0', 'B1', 'B2', 'B3','B4']})
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K5  A1  B1
# 2  K1  A2  B2
# 3  K2  A3  B3
# 4  K3  A4  B4

# %%
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3','K4'],
                     'A': ['A0', 'A1', 'A2', 'A3','A8'],
                    'B': ['B0', 'B1', 'B2', 'B3','B9']})
right
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3
# 4  K4  A8  B9

# %% [markdown]
# Make the column "key" the index of both dataframes

# %%
left.index = left.key
left.drop(axis=1,columns=['key'], inplace=True)
right.index = right.key
right.drop(axis=1,columns=['key'],inplace=True)

# %%
right
# Out:
#       A   B
# key
# K0   A0  B0
# K1   A1  B1
# K2   A2  B2
# K3   A3  B3
# K4   A8  B9

# %%
left
# Out:
#       A   B
# key
# K0   A0  B0
# K5   A1  B1
# K1   A2  B2
# K2   A3  B3
# K3   A4  B4

# %%
df = left.append(right)
df
# Out:
#       A   B
# key
# K0   A0  B0
# K5   A1  B1
# K1   A2  B2
# K2   A3  B3
# K3   A4  B4
# K0   A0  B0
# K1   A1  B1
# K2   A2  B2
# K3   A3  B3
# K4   A8  B9

# %% [markdown]
# Select all rows that occur between key 'K5' and 'K4'

# %%
df.loc['K5':'K4']
# Out:
#       A   B
# key
# K5   A1  B1
# K1   A2  B2
# K2   A3  B3
# K3   A4  B4
# K0   A0  B0
# K1   A1  B1
# K2   A2  B2
# K3   A3  B3
# K4   A8  B9

# %% [markdown]
# Select all rows that occur between key 'K0' and 'K1'

# %%
df.loc['K0':'K1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-e8191a34d246> in <module>
# ----> 1 df.loc['K0':'K1']
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1795         if isinstance(key, slice):
#    1796             self._validate_key(key, axis)
# -> 1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
#    1799             return self._getbool_axis(key, axis=axis)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1452         labels = obj._get_axis(axis)
#    1453         indexer = labels.slice_indexer(
# -> 1454             slice_obj.start, slice_obj.stop, slice_obj.step, kind=self.name
#    1455         )
#    1456
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    5032         slice(1, 3)
#    5033         """
# -> 5034         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5035
#    5036         # return a slice
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5246         start_slice = None
#    5247         if start is not None:
# -> 5248             start_slice = self.get_slice_bound(start, "left", kind)
#    5249         if start_slice is None:
#    5250             start_slice = 0
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5180                 raise KeyError(
#    5181                     "Cannot get %s slice bound for non-unique "
# -> 5182                     "label: %r" % (side, original_label)
#    5183                 )
#    5184
#
# KeyError: "Cannot get left slice bound for non-unique label: 'K0'"

# %%
teachers = pd.DataFrame({'NetID':['sp6543','re2312','cp7174','re2312','sp6543'], 
                         'Course':['DSUA111','DSGA1001','DSGA1002','DSGA1003','DSGA1004']})
teachers
# Out:
#     NetID    Course
# 0  sp6543   DSUA111
# 1  re2312  DSGA1001
# 2  cp7174  DSGA1002
# 3  re2312  DSGA1003
# 4  sp6543  DSGA1004

# %%
students = pd.DataFrame({'NetID':['aa6252','sa5154','ra2911','ka2146','mb6685','fc1368','ka2146','sa5154','ra2911'], 
                         'Course':['DSGA1001','DSGA1001','DSGA1001','DSGA1001','DSGA1001','DSGA1001','DSUA112','DSUA112','DSUA112'], 
                         'Grade':[98,65,90,72,87,93,45,67,92]})
students
# Out:
#     NetID    Course  Grade
# 0  aa6252  DSGA1001     98
# 1  sa5154  DSGA1001     65
# 2  ra2911  DSGA1001     90
# 3  ka2146  DSGA1001     72
# 4  mb6685  DSGA1001     87
# 5  fc1368  DSGA1001     93
# 6  ka2146   DSUA112     45
# 7  sa5154   DSUA112     67
# 8  ra2911   DSUA112     92

# %% [markdown]
# How do we get the average score of each student across all the courses?

# %%
students.groupby('NetID').agg({'Grade':'mean'})
# Out:
#         Grade
# NetID
# aa6252   98.0
# fc1368   93.0
# ka2146   58.5
# mb6685   87.0
# ra2911   91.0
# sa5154   66.0

# %% [markdown]
# How do we get the average score of each student across all the courses along with the number of courses they have done?

# %%
students.groupby('NetID').agg({'Grade':'mean','Course':'count'})
# Out:
#         Grade  Course
# NetID
# aa6252   98.0       1
# fc1368   93.0       1
# ka2146   58.5       2
# mb6685   87.0       1
# ra2911   91.0       2
# sa5154   66.0       2

# %% [markdown]
# How do we get the average score of each student across all the courses along with the list of courses they have done?

# %%
students.groupby('NetID').agg({'Grade':'mean','Course':list})
# Out:
#         Grade               Course
# NetID
# aa6252   98.0           [DSGA1001]
# fc1368   93.0           [DSGA1001]
# ka2146   58.5  [DSGA1001, DSUA112]
# mb6685   87.0           [DSGA1001]
# ra2911   91.0  [DSGA1001, DSUA112]
# sa5154   66.0  [DSGA1001, DSUA112]

# %% [markdown]
# ## Merge, join and concat

# %% [markdown]
# Let's say that we want to merge both the teachers and students dataframe so that we have one single dataframe with teachers netID, students netID, grade and course. Which pandas function do we use?

# %%
pd.merge(left=teachers, right=students, how='outer', left_on='Course', right_on='Course', suffixes=('_prof','_student'))
# Out:
#    NetID_prof    Course NetID_student  Grade
# 0      sp6543   DSUA111           NaN    NaN
# 1      re2312  DSGA1001        aa6252   98.0
# 2      re2312  DSGA1001        sa5154   65.0
# 3      re2312  DSGA1001        ra2911   90.0
# 4      re2312  DSGA1001        ka2146   72.0
# 5      re2312  DSGA1001        mb6685   87.0
# 6      re2312  DSGA1001        fc1368   93.0
# 7      cp7174  DSGA1002           NaN    NaN
# 8      re2312  DSGA1003           NaN    NaN
# 9      sp6543  DSGA1004           NaN    NaN
# 10        NaN   DSUA112        ka2146   45.0
# 11        NaN   DSUA112        sa5154   67.0
# 12        NaN   DSUA112        ra2911   92.0

# %%
pd.merge(left=teachers, right=students, how='inner', left_on='Course', right_on='Course', suffixes=('_prof','_student'))
# Out:
#   NetID_prof    Course NetID_student  Grade
# 0     re2312  DSGA1001        aa6252     98
# 1     re2312  DSGA1001        sa5154     65
# 2     re2312  DSGA1001        ra2911     90
# 3     re2312  DSGA1001        ka2146     72
# 4     re2312  DSGA1001        mb6685     87
# 5     re2312  DSGA1001        fc1368     93

# %%
pd.merge(left=teachers, right=students, how='left', left_on='Course', right_on='Course', suffixes=('_prof','_student'))
# Out:
#   NetID_prof    Course NetID_student  Grade
# 0     sp6543   DSUA111           NaN    NaN
# 1     re2312  DSGA1001        aa6252   98.0
# 2     re2312  DSGA1001        sa5154   65.0
# 3     re2312  DSGA1001        ra2911   90.0
# 4     re2312  DSGA1001        ka2146   72.0
# 5     re2312  DSGA1001        mb6685   87.0
# 6     re2312  DSGA1001        fc1368   93.0
# 7     cp7174  DSGA1002           NaN    NaN
# 8     re2312  DSGA1003           NaN    NaN
# 9     sp6543  DSGA1004           NaN    NaN

# %%
pd.merge(left=teachers, right=students, how='right', left_on='Course', right_on='Course', suffixes=('_prof','_student'))
# Out:
#   NetID_prof    Course NetID_student  Grade
# 0     re2312  DSGA1001        aa6252     98
# 1     re2312  DSGA1001        sa5154     65
# 2     re2312  DSGA1001        ra2911     90
# 3     re2312  DSGA1001        ka2146     72
# 4     re2312  DSGA1001        mb6685     87
# 5     re2312  DSGA1001        fc1368     93
# 6        NaN   DSUA112        ka2146     45
# 7        NaN   DSUA112        sa5154     67
# 8        NaN   DSUA112        ra2911     92

# %%
teachers.join(students, on='Course',how='outer',lsuffix='_prof',rsuffix='_student')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-2f6af64cd1c2> in <module>
# ----> 1 teachers.join(students, on='Course',how='outer',lsuffix='_prof',rsuffix='_student')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7244         # For SparseDataFrame's benefit
#    7245         return self._join_compat(
# -> 7246             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7247         )
#    7248
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7267                 right_index=True,
#    7268                 suffixes=(lsuffix, rsuffix),
# -> 7269                 sort=sort,
#    7270             )
#    7271         else:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     628         # validate the merge keys dtypes. We may need to coerce
#     629         # to avoid incompat dtypes
# --> 630         self._maybe_coerce_merge_keys()
#     631
#     632         # If argument passed to validate,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1136                     inferred_right in string_types and inferred_left not in string_types
#    1137                 ):
# -> 1138                     raise ValueError(msg)
#    1139
#    1140             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %%
teachers.set_index('Course').join(students.set_index('Course'),how='outer',lsuffix='_prof',rsuffix='_student')
# Out:
#          NetID_prof NetID_student  Grade
# Course
# DSGA1001     re2312        aa6252   98.0
# DSGA1001     re2312        sa5154   65.0
# DSGA1001     re2312        ra2911   90.0
# DSGA1001     re2312        ka2146   72.0
# DSGA1001     re2312        mb6685   87.0
# DSGA1001     re2312        fc1368   93.0
# DSGA1002     cp7174           NaN    NaN
# DSGA1003     re2312           NaN    NaN
# DSGA1004     sp6543           NaN    NaN
# DSUA111      sp6543           NaN    NaN
# DSUA112         NaN        ka2146   45.0
# DSUA112         NaN        sa5154   67.0
# DSUA112         NaN        ra2911   92.0

# %%
pd.concat([teachers,students],sort=False)
# Out:
#     NetID    Course  Grade
# 0  sp6543   DSUA111    NaN
# 1  re2312  DSGA1001    NaN
# 2  cp7174  DSGA1002    NaN
# 3  re2312  DSGA1003    NaN
# 4  sp6543  DSGA1004    NaN
# 0  aa6252  DSGA1001   98.0
# 1  sa5154  DSGA1001   65.0
# 2  ra2911  DSGA1001   90.0
# 3  ka2146  DSGA1001   72.0
# 4  mb6685  DSGA1001   87.0
# 5  fc1368  DSGA1001   93.0
# 6  ka2146   DSUA112   45.0
# 7  sa5154   DSUA112   67.0
# 8  ra2911   DSUA112   92.0

# %%
pd.concat([teachers,students],sort=False,ignore_index=True)
# Out:
#      NetID    Course  Grade
# 0   sp6543   DSUA111    NaN
# 1   re2312  DSGA1001    NaN
# 2   cp7174  DSGA1002    NaN
# 3   re2312  DSGA1003    NaN
# 4   sp6543  DSGA1004    NaN
# 5   aa6252  DSGA1001   98.0
# 6   sa5154  DSGA1001   65.0
# 7   ra2911  DSGA1001   90.0
# 8   ka2146  DSGA1001   72.0
# 9   mb6685  DSGA1001   87.0
# 10  fc1368  DSGA1001   93.0
# 11  ka2146   DSUA112   45.0
# 12  sa5154   DSUA112   67.0
# 13  ra2911   DSUA112   92.0

# %%
pd.concat([teachers,students],sort=False,ignore_index=True)
# Out:
#      NetID    Course  Grade
# 0   sp6543   DSUA111    NaN
# 1   re2312  DSGA1001    NaN
# 2   cp7174  DSGA1002    NaN
# 3   re2312  DSGA1003    NaN
# 4   sp6543  DSGA1004    NaN
# 5   aa6252  DSGA1001   98.0
# 6   sa5154  DSGA1001   65.0
# 7   ra2911  DSGA1001   90.0
# 8   ka2146  DSGA1001   72.0
# 9   mb6685  DSGA1001   87.0
# 10  fc1368  DSGA1001   93.0
# 11  ka2146   DSUA112   45.0
# 12  sa5154   DSUA112   67.0
# 13  ra2911   DSUA112   92.0

# %%
pd.concat([teachers,students],sort=False,keys=['prof','student'])
# Out:
#             NetID    Course  Grade
# prof    0  sp6543   DSUA111    NaN
#         1  re2312  DSGA1001    NaN
#         2  cp7174  DSGA1002    NaN
#         3  re2312  DSGA1003    NaN
#         4  sp6543  DSGA1004    NaN
# student 0  aa6252  DSGA1001   98.0
#         1  sa5154  DSGA1001   65.0
#         2  ra2911  DSGA1001   90.0
#         3  ka2146  DSGA1001   72.0
#         4  mb6685  DSGA1001   87.0
#         5  fc1368  DSGA1001   93.0
#         6  ka2146   DSUA112   45.0
#         7  sa5154   DSUA112   67.0
#         8  ra2911   DSUA112   92.0
